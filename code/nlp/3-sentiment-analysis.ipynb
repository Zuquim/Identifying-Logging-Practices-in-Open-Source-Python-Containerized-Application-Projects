# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# ## Introduction

# %% [markdown]
# So far, all of the analysis we've done has been pretty generic - looking at counts, creating scatter plots, etc. These techniques could be applied to numeric data as well.
#
# When it comes to text data, there are a few popular techniques that we'll be going through in the next few notebooks, starting with sentiment analysis. A few key points to remember with sentiment analysis.
#
# 1. **TextBlob Module:** Linguistic researchers have labeled the sentiment of words based on their domain expertise. Sentiment of words can vary based on where it is in a sentence. The TextBlob module allows us to take advantage of these labels.
# 2. **Sentiment Labels:** Each word in a corpus is labeled in terms of polarity and subjectivity (there are more labels as well, but we're going to ignore them for now). A corpus' sentiment is the average of these.
#    * **Polarity**: How positive or negative a word is. -1 is very negative. +1 is very positive.
#    * **Subjectivity**: How subjective, or opinionated a word is. 0 is fact. +1 is very much an opinion.
#
# For more info on how TextBlob coded up its [sentiment function](https://planspace.org/20150607-textblob_sentiment/).
#
# Let's take a look at the sentiment of the various transcripts, both overall and throughout the comedy routine.

# %% [markdown]
# ## Sentiment of Routine

# %%
# We'll start by reading in the corpus, which preserves word order
import pandas as pd

verbosity_levels = ["DEBUG", "INFO", "WARNING", "ERROR", "CRITICAL"]
verbosity_levels.sort()

data = pd.read_pickle('corpus.pkl')
data["level"] = verbosity_levels
data
# Out:
#                                                     content     level
# CRITICAL  "Failed getting list of jobs" "error, no place...  CRITICAL
# DEBUG     json.dumps( { 'response': { 'url': error.url, ...     DEBUG
# ERROR     "Start failed." "Stop failed." "Shutdown Watch...     ERROR
# INFO      "loading detect modules based on event_log" "s...      INFO
# WARNING   "index {name} not found.".format(name=index_na...   WARNING

# %%
print(data[data.level == 'INFO'].content[0])
# Out:
# ame) "=> init {}.bias as 0".format(name) "=> loading pretrained model {}".format(pretrained) "=> init weights from normal distribution" "=> loading model from {}".format(cfg.TEST.MODEL_FILE) "=> loading model from {}".format(model_state_file) "=> loading checkpoint '{}'".format(checkpoint_file) "=> loaded checkpoint '{}' (epoch {})".format( checkpoint_file, checkpoint["epoch"]  "=> saving checkpoint to {}".format(final_output_dir) "=> saving final model state to {}".format(final_model_state_file) "train", self.meta_info["iter"], self.epoch_info "train", self.meta_info["iter"], self.iter_info "Initialized model weights from {} ...".format(model) "Current epoch is %d." % self.cur_epoch "Generating training graph on {} GPUs ...".format(self.cfg.nr_gpus "Initialize saver ..." "Initialize all variables ..." "Start training ..." " ".join(screen) "Generating testing graph on {} GPUs ...".format(self.cfg.nr_gpus "you chose RMSProp, decreasing lr by a factor of 10" "Resume training with {} from epoch {}".format(ctx_str, resume) "Start finetuning with {} from epoch {}".format(ctx_str, finetune) "Removed %s" % k "Start training with {} from pretrained model {}".format( ctx_str, pretrained  "Experimental: start training from scratch with {}".format(ctx_str) "Freezed parameters: [" + ",".join(fixed_param_names) + "]" "Start evaluation on {} images".format(len(dataset)) "Total inference time: {} ({} s / img per device, on {} devices)".format( total_time_str, total_time * num_devices / len(dataset), num_devices  "Evaluating bbox proposals" "Preparing results for COCO format" "Preparing bbox results" "Preparing segm results" "Evaluating predictions" "Start training" meters.delimiter.join( [ "eta: {eta}", "iter: {iter}", "{meters}", "lr: {lr:.6f}", "max mem: {memory:.0f}", ] ).format( eta=eta_string, iter=iteration, meters=str(meters), lr=optimizer.param_groups[0]["lr"], memory=torch.cuda.max_memory_allocated() / 1024.0 / 1024.0,  "Total training time: {} ({:.4f} s / it)".format( total_time_str, total_training_time / (max_iter "Remapping C2 weights" "C2 name: {: <{}} mapped name: {}".format(k, max_c2_key_size, key_map[k] "Saving checkpoint to {}".format(save_file) "No checkpoint found. Initializing model from scratch" "Loading checkpoint from {}".format(f) "Loading optimizer from {}".format(f) "Loading scheduler from {}".format(f) "{} points to {}".format(f, catalog_f) "url {} cached in {}".format(f, cached_f) "Using {} GPUs".format(num_gpus) "Collecting env info (might take some time)" "\n" + collect_env_info() "Using {} GPUs".format(num_gpus) "Collecting env info (might take some time)" "\n" + collect_env_info() "Loaded configuration file {}".format(args.config_file) "Running with config:\n{}".format(cfg) "load model from: {}".format(pretrained) "Distributed training: {}".format(distributed) "Set random seed to {}".format(args.seed) "dex2smali successfully!" "dex2smali unsuccessfully!" "[VulScanEngine] - %d entry point found." % len(activityEntryList) "[VulScanEngine] - Create a DVM instance." "[VulScanEngine] - Ready to interpret the smali bytecode." "[VulScanEngine] - Process the final result and report it." "[VulScanEngine] - Compiled failed,please make sure if the project path is corrected."  "package successfully！" "package unsuccessfully！" "dex2smali successfully!" "dex2smali unsuccessfully!" "[VulScanEngine] - %d entry point found." % len(activityEntryList) "[VulScanEngine] - Create a DVM instance." "[VulScanEngine] - Ready to interpret the smali bytecode." "[VulScanEngine] - Process the final result and report it." "unsupportted type of file." "[Finder] - 类信息 %s" % cls.clase_padre "[Finder] - 方法信息 %s" % cls.metodo_padre "[Finder] - 坐标信息 %s" % cls.etiqueta "[Finder] - 指令信息 %s" % cls.instructiones "[Finder] - 分支信息 %s" % cls.bifurcaciones "[init] - edegs %s  %s" % (k0, k1) "代码块=>%s" % node "[DVM] - Start to build  cfg %d from the entry：%s"%(entry_count,activityEntry.encode('utf-8')) "[Graph] - build the cfg successfully." "[Init] - 	sin ...

# %%
# Create quick lambda functions to find the polarity and subjectivity of each routine
# Terminal / Anaconda Navigator: conda install -c conda-forge textblob
from textblob import TextBlob

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

data['polarity'] = data['content'].apply(pol)
data['subjectivity'] = data['content'].apply(sub)
data
# Out:
#                                                     content     level  \
# CRITICAL  "Failed getting list of jobs" "error, no place...  CRITICAL
# DEBUG     json.dumps( { 'response': { 'url': error.url, ...     DEBUG
# ERROR     "Start failed." "Stop failed." "Shutdown Watch...     ERROR
# INFO      "loading detect modules based on event_log" "s...      INFO
# WARNING   "index {name} not found.".format(name=index_na...   WARNING
#
#           polarity  subjectivity
# CRITICAL -0.213064      0.539409
# DEBUG    -0.230858      0.608451
# ERROR    -0.327732      0.513003
# INFO     -0.190542      0.604105
# WARNING  -0.177825      0.511139

# %%
# Let's plot the results
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10, 8]

for index, level in enumerate(data.index):
    x = data.polarity.loc[level]
    y = data.subjectivity.loc[level]
    plt.scatter(x, y, color='blue')
    plt.text(x+.001, y+.001, data['level'][index], fontsize=10)
    plt.xlim(-.35, 0) 
    
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<-- Negative -------- Positive -->', fontsize=15)
plt.ylabel('<-- Facts -------- Opinions -->', fontsize=15)

plt.show()
